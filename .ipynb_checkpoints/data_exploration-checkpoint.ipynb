# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_values = pd.read_csv("./dataset/train_values.csv")
df_labels = pd.read_csv("./dataset/train_labels.csv")

df = pd.merge(df_values, df_labels, how='inner', on = 'building_id')

df['damage_grade'] = df_labels['damage_grade']

# %%
font = {'family' : 'normal',
        'size'   : 20}

plt.rc('font', **font)
plt.rcParams.update({'font.size': 20})
sns.set(font="Lucida Sans Unicode")
sns.set_theme(style='white')

# %% [markdown]
# # 01 First considerations on data
#
# We can see from the processing below that none of the dimension contains null values. We have 38 features + 1 target variable. The total number of entries is 260601. The target labels are unbalanced. The label 2 seems to be the most frequent and the label 1 the less frequent label. This can be problematic for the model.

# %%
df.describe().T.style.background_gradient(cmap = 'hot', low = 0.4, high = 0.1, axis = 0)
# Out:
# <style type="text/css">
# #T_2920d_row0_col0, #T_2920d_row1_col0, #T_2920d_row2_col0, #T_2920d_row3_col0, #T_2920d_row4_col0, #T_2920d_row5_col0, #T_2920d_row6_col0, #T_2920d_row7_col0, #T_2920d_row8_col0, #T_2920d_row9_col0, #T_2920d_row10_col0, #T_2920d_row11_col0, #T_2920d_row12_col0, #T_2920d_row13_col0, #T_2920d_row14_col0, #T_2920d_row15_col0, #T_2920d_row16_col0, #T_2920d_row17_col0, #T_2920d_row18_col0, #T_2920d_row19_col0, #T_2920d_row20_col0, #T_2920d_row21_col0, #T_2920d_row22_col0, #T_2920d_row23_col0, #T_2920d_row24_col0, #T_2920d_row25_col0, #T_2920d_row26_col0, #T_2920d_row27_col0, #T_2920d_row28_col0, #T_2920d_row29_col0, #T_2920d_row30_col0, #T_2920d_row31_col0 {
#   background-color: #0b0000;
#   color: #f1f1f1;
# }
# #T_2920d_row0_col1, #T_2920d_row0_col2, #T_2920d_row0_col3, #T_2920d_row0_col4, #T_2920d_row0_col5, #T_2920d_row0_col6, #T_2920d_row0_col7 {
#   background-color: #ffffbc;
#   color: #000000;
# }
# #T_2920d_row1_col1, #T_2920d_row1_col2, #T_2920d_row1_col3, #T_2920d_row1_col4, #T_2920d_row1_col5, #T_2920d_row1_col6, #T_2920d_row1_col7, #T_2920d_row2_col1, #T_2920d_row2_col2, #T_2920d_row2_col3, #T_2920d_row2_col4, #T_2920d_row2_col5, #T_2920d_row2_col6, #T_2920d_row2_col7, #T_2920d_row3_col3, #T_2920d_row4_col1, #T_2920d_row4_col2, #T_2920d_row4_col4, #T_2920d_row4_col5, #T_2920d_row4_col6, #T_2920d_row4_col7, #T_2920d_row5_col1, #T_2920d_row5_col2, #T_2920d_row5_col3, #T_2920d_row5_col4, #T_2920d_row5_col5, #T_2920d_row5_col6, #T_2920d_row5_col7, #T_2920d_row6_col1, #T_2920d_row6_col2, #T_2920d_row6_col4, #T_2920d_row6_col5, #T_2920d_row6_col6, #T_2920d_row6_col7, #T_2920d_row7_col1, #T_2920d_row7_col2, #T_2920d_row7_col4, #T_2920d_row7_col5, #T_2920d_row7_col6, #T_2920d_row7_col7, #T_2920d_row8_col1, #T_2920d_row8_col2, #T_2920d_row8_col3, #T_2920d_row8_col4, #T_2920d_row8_col5, #T_2920d_row8_col6, #T_2920d_row8_col7, #T_2920d_row9_col1, #T_2920d_row9_col2, #T_2920d_row9_col3, #T_2920d_row9_col4, #T_2920d_row9_col5, #T_2920d_row9_col6, #T_2920d_row9_col7, #T_2920d_row10_col1, #T_2920d_row10_col2, #T_2920d_row10_col3, #T_2920d_row10_col4, #T_2920d_row10_col5, #T_2920d_row10_col6, #T_2920d_row10_col7, #T_2920d_row11_col1, #T_2920d_row11_col2, #T_2920d_row11_col3, #T_2920d_row11_col4, #T_2920d_row11_col5, #T_2920d_row11_col6, #T_2920d_row11_col7, #T_2920d_row12_col1, #T_2920d_row12_col2, #T_2920d_row12_col3, #T_2920d_row12_col4, #T_2920d_row12_col5, #T_2920d_row12_col6, #T_2920d_row12_col7, #T_2920d_row13_col1, #T_2920d_row13_col2, #T_2920d_row13_col3, #T_2920d_row13_col4, #T_2920d_row13_col5, #T_2920d_row13_col6, #T_2920d_row13_col7, #T_2920d_row14_col1, #T_2920d_row14_col2, #T_2920d_row14_col3, #T_2920d_row14_col4, #T_2920d_row14_col5, #T_2920d_row14_col6, #T_2920d_row14_col7, #T_2920d_row15_col1, #T_2920d_row15_col2, #T_2920d_row15_col3, #T_2920d_row15_col4, #T_2920d_row15_col5, #T_2920d_row15_col6, #T_2920d_row15_col7, #T_2920d_row16_col1, #T_2920d_row16_col2, #T_2920d_row16_col3, #T_2920d_row16_col4, #T_2920d_row16_col5, #T_2920d_row16_col6, #T_2920d_row16_col7, #T_2920d_row17_col1, #T_2920d_row17_col2, #T_2920d_row17_col3, #T_2920d_row17_col4, #T_2920d_row17_col5, #T_2920d_row17_col6, #T_2920d_row17_col7, #T_2920d_row18_col1, #T_2920d_row18_col2, #T_2920d_row18_col3, #T_2920d_row18_col4, #T_2920d_row18_col5, #T_2920d_row18_col6, #T_2920d_row18_col7, #T_2920d_row19_col1, #T_2920d_row19_col2, #T_2920d_row19_col3, #T_2920d_row19_col4, #T_2920d_row19_col5, #T_2920d_row19_col6, #T_2920d_row19_col7, #T_2920d_row20_col1, #T_2920d_row20_col2, #T_2920d_row20_col3, #T_2920d_row20_col4, #T_2920d_row20_col5, #T_2920d_row20_col6, #T_2920d_row20_col7, #T_2920d_row21_col1, #T_2920d_row21_col2, #T_2920d_row21_col3, #T_2920d_row21_col4, #T_2920d_row21_col5, #T_2920d_row21_col6, #T_2920d_row21_col7, #T_2920d_row22_col1, #T_2920d_row22_col2, #T_2920d_row22_col3, #T_2920d_row22_col4, #T_2920d_row22_col5, #T_2920d_row22_col6, #T_2920d_row22_col7, #T_2920d_row23_col1, #T_2920d_row23_col2, #T_2920d_row23_col3, #T_2920d_row23_col4, #T_2920d_row23_col5, #T_2920d_row23_col6, #T_2920d_row23_col7, #T_2920d_row24_col1, #T_2920d_row24_col2, #T_2920d_row24_col3, #T_2920d_row24_col4, #T_2920d_row24_col5, #T_2920d_row24_col6, #T_2920d_row24_col7, #T_2920d_row25_col1, #T_2920d_row25_col2, #T_2920d_row25_col3, #T_2920d_row25_col4, #T_2920d_row25_col5, #T_2920d_row25_col6, #T_2920d_row25_col7, #T_2920d_row26_col1, #T_2920d_row26_col2, #T_2920d_row26_col3, #T_2920d_row26_col4, #T_2920d_row26_col5, #T_2920d_row26_col6, #T_2920d_row26_col7, #T_2920d_row27_col1, #T_2920d_row27_col2, #T_2920d_row27_col3, #T_2920d_row27_col4, #T_2920d_row27_col5, #T_2920d_row27_col6, #T_2920d_row27_col7, #T_2920d_row28_col1, #T_2920d_row28_col2, #T_2920d_row28_col3, #T_2920d_row28_col4, #T_2920d_row28_col5, #T_2920d_row28_col6, #T_2920d_row28_col7, #T_2920d_row29_col1, #T_2920d_row29_col2, #T_2920d_row29_col3, #T_2920d_row29_col4, #T_2920d_row29_col5, #T_2920d_row29_col6, # ...
#   background-color: #bd0000;
#   color: #f1f1f1;
# }
# #T_2920d_row3_col1, #T_2920d_row3_col2, #T_2920d_row3_col4, #T_2920d_row3_col5, #T_2920d_row3_col6, #T_2920d_row3_col7 {
#   background-color: #c20000;
#   color: #f1f1f1;
# }
# #T_2920d_row4_col3, #T_2920d_row6_col3, #T_2920d_row31_col3 {
#   background-color: #ff2c00;
#   color: #f1f1f1;
# }
# #T_2920d_row7_col3 {
#   background-color: #ff9d00;
#   color: #000000;
# }
# </style>
# <table id="T_2920d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2920d_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_2920d_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_2920d_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_2920d_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_2920d_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_2920d_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_2920d_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_2920d_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2920d_level0_row0" class="row_heading level0 row0" >building_id</th>
#       <td id="T_2920d_row0_col0" class="data row0 col0" >260601.000000</td>
#       <td id="T_2920d_row0_col1" class="data row0 col1" >525675.482773</td>
#       <td id="T_2920d_row0_col2" class="data row0 col2" >304544.999032</td>
#       <td id="T_2920d_row0_col3" class="data row0 col3" >4.000000</td>
#       <td id="T_2920d_row0_col4" class="data row0 col4" >261190.000000</td>
#       <td id="T_2920d_row0_col5" class="data row0 col5" >525757.000000</td>
#       <td id="T_2920d_row0_col6" class="data row0 col6" >789762.000000</td>
#       <td id="T_2920d_row0_col7" class="data row0 col7" >1052934.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2920d_level0_row1" class="row_heading level0 row1" >geo_level_1_id</th>
#       <td id="T_2920d_row1_col0" class="data row1 col0" >260601.000000</td>
#       <td id="T_2920d_row1_col1" class="data row1 col1" >13.900353</td>
#       <td id="T_2920d_row1_col2" class="data row1 col2" >8.033617</td>
#       <td id="T_2920d_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_2920d_row1_col4" class="data row1 col4" >7.000000</td>
#       <td id="T_2920d_row1_col5" class="data row1 col5" >12.000000</td>
#       <td id="T_2920d_row1_col6" class="data row1 col6" >21.000000</td>
#       <td id="T_2920d_row1_col7" class="data row1 col7" >30.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2920d_level0_row2" class="row_heading level0 row2" >geo_level_2_id</th>
#       <td id="T_2920d_row2_col0" class="data row2 col0" >260601.000000</td>
#       <td id="T_2920d_row2_col1" class="data row2 col1" >701.074685</td>

# %%
df.describe(include="object").T
# Out:
#                          count unique top    freq
# land_surface_condition  260601      3   t  216757
# foundation_type         260601      5   r  219196
# roof_type               260601      3   n  182842
# ground_floor_type       260601      5   f  209619
# other_floor_type        260601      4   q  165282
# position                260601      4   s  202090
# plan_configuration      260601     10   d  250072
# legal_ownership_status  260601      4   v  250939

# %%
# Check if there exists some null attribute

any(df.isnull().sum().T != 0)
# Out:
# False

# %%
_, _ = plt.subplots(figsize = (8, 6))

sns.countplot(x = df['damage_grade'], palette=['#ac2432', '#452c28', '#9b7d52'])

plt.grid(True)
plt.show()

# %% [markdown]
# # 02  Analysis of numerical features

# %%
fig, axs = plt.subplots(4, 2, figsize = (15, 8))

sns.histplot(df['geo_level_1_id'], ax = axs[0][0], color = 'brown')
sns.histplot(df['geo_level_2_id'], ax = axs[0][1], color = 'brown')
sns.histplot(df['geo_level_3_id'], ax = axs[1][0], color = 'brown')
sns.histplot(df['count_floors_pre_eq'], ax = axs[1][1], color = 'brown')
sns.histplot(df['age'], ax =  axs[2][0], color = 'brown')
sns.histplot(df['area_percentage'], ax = axs[2][1], color = 'brown')
sns.histplot(df['height_percentage'], ax = axs[3][0], color = 'brown')
sns.histplot(df['count_families'], ax = axs[3][1], color = 'brown')

plt.show()

# %% [markdown]
# The data concerning the geo levels 2 and 3 seems almost uniformly distributed. The geo level 1, instead is more complex. It is difficult to analyze the other attributes from these plots due to the presence of outliers. We will make a separate plot. In all cases, though, seems like a normalization or the use of a log scale would benefit. Then the next step would be to analyze the same features with respect to the target variable.

# %%
_, axs = plt.subplots(2, 2, figsize = (20, 10))

"""
Recall that a boxplot is divaded in 5 number summary: minimum, maximum, sample median, and the first and the third quantiles.
The minimum (0th percentile) is the lows data point in the data set excluding any outliers.
The maximum (100th percentile) is the highest data point in the data set excluding any outliers.
The median (50th percentile) is the middle value in the data set.
The first quantile (25th percentile) is the median of the lower half of the data set.
The third quantile (75th percentile) is the median of the upper half of the data set.

(Source: Wikipedia)

"""

sns.boxplot(data = df, x = "height_percentage", y = "damage_grade", orient = "h", ax = axs[0][0], palette=['#ac2432', '#452c28', '#9b7d52'])
sns.countplot(data = df, x = "height_percentage", hue = "damage_grade", ax = axs[0][1], palette=['#ac2432', '#452c28', '#9b7d52'])
sns.boxplot(data = df, x = "area_percentage", y = "damage_grade", orient = "h", ax = axs[1][0], palette=['#ac2432', '#452c28', '#9b7d52'])
sns.countplot(data = df, x = "area_percentage", hue = "damage_grade", ax = axs[1][1], palette=['#ac2432', '#452c28', '#9b7d52'])

axs[0][1].set_xticks([])
axs[1][1].set_xticks([])

axs[0][0].grid(visible=True)
axs[0][1].grid(visible=True)
axs[1][0].grid(visible=True)
axs[1][1].grid(visible=True)


plt.grid(True)

plt.show()

# %% [markdown]
# The height percentage seems not to go beyond the 32%. The area percentage is a difficult feature, since the high presence of value that cross the std threshold. Maybe it would be better to normalize it with a MinMaxScaler, even though the range of values stands between 0 and 100 which is not a very large range.

# %%
_, axs = plt.subplots(1, 2, figsize = (20, 6))

sns.boxplot(data = df, x = "age", y = "damage_grade", ax = axs[0], orient = "h", palette=['#ac2432', '#452c28', '#9b7d52'])
sns.countplot(data = df, x = "age", hue = "damage_grade", ax =  axs[1], palette=['#ac2432', '#452c28', '#9b7d52'])

plt.xticks(rotation = 70)

axs[0].grid(visible=True)
axs[1].grid(visible=True)

plt.show()

# %% [markdown]
# Here the values need for certain a normalization. The presence of outliers can mislead a predictor and it would be better for us to deal with those.
#
# For curiosity: Kasthamandap is a building 1000 y.o. in the region and it was the oldest building in Kathmandu. All these outliers exists.

# %%
_, axs = plt.subplots(2, 2, figsize = (15, 10))

sns.boxplot(data = df, x = 'count_floors_pre_eq', y = 'damage_grade', ax = axs[0][0], orient = 'h', palette=['#ac2432', '#452c28', '#9b7d52'])
sns.countplot(data = df, x = 'count_floors_pre_eq', hue = 'damage_grade', ax = axs[0][1], palette=['#ac2432', '#452c28', '#9b7d52'])
sns.boxplot(data = df, x = 'count_families', y = 'damage_grade', ax = axs[1][0], orient = 'h', palette=['#ac2432', '#452c28', '#9b7d52'])
sns.countplot(data = df, x = 'count_families', hue = 'damage_grade', ax = axs[1][1], palette=['#ac2432', '#452c28', '#9b7d52'])

axs[0][0].grid(visible=True)
axs[0][1].grid(visible=True)
axs[1][0].grid(visible=True)
axs[1][1].grid(visible=True)

plt.show()

# %% [markdown]
# Even in this case, there is the presence of outliers. But in this case they can be neglected maybe since the range of values is not very large and the number of data outside the 75th percentile is very low.

# %% [markdown]
# # 03 Correlation Analysis
#
# It seems that not many features are correlated. From the analysis above, only high correlation seems to be between count_floors_pre_eq and height_percentage (this was expected since higher buildings have more floors), and has_secondary_use and has_secondary_use_agriculture. The correlation though is not high enough to lead to a certain discard of the features.

# %%
corr_matrix = df.corr().abs()

plt.subplots(figsize = (10, 8))

sns.heatmap(corr_matrix, cmap = 'copper')

plt.show()

# %%
# We select the upper triangular matrix (no difference with the lower)

upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k = 1).astype(bool))

high_corr_features = [column for column in upper_tri.columns if any(upper_tri[column] > 0.7)]

plt.subplots(figsize = (8, 6))

sns.heatmap(corr_matrix[high_corr_features], cmap = 'copper', annot = True)

plt.show()
